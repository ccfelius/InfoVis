# %%
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("soc-redditHyperlinks-body.tsv", sep="\t", header =0)

# %%
subreddits = df['SOURCE_SUBREDDIT'].value_counts()

# %%
df.TIMESTAMP.describe()
# Out:
# count                  286561
# unique                 248453
# top       2014-08-20 14:40:53
# freq                      360
# Name: TIMESTAMP, dtype: object

# %%
subreddits.size
# Out:
# 27863

# %%
subreddits
# Out:
# subredditdrama      4665
# circlebroke         2358
# shitliberalssay     1968
# outoftheloop        1958
# copypasta           1824
#                     ...
# gayrp                  1
# dr_doctore             1
# ml16                   1
# neutralmilkhotel       1
# poems                  1
# Name: SOURCE_SUBREDDIT, Length: 27863, dtype: int64

# %%
df[0:300]
# Out:
#     SOURCE_SUBREDDIT TARGET_SUBREDDIT  POST_ID            TIMESTAMP  \
# 0    leagueoflegends  teamredditteams  1u4nrps  2013-12-31 16:39:58
# 1         theredlion           soccer   1u4qkd  2013-12-31 18:18:37
# 2       inlandempire           bikela  1u4qlzs  2014-01-01 14:54:35
# 3                nfl              cfb  1u4sjvs  2013-12-31 17:37:55
# 4         playmygame          gamedev  1u4w5ss  2014-01-01 02:51:13
# ..               ...              ...      ...                  ...
# 295     outoftheloop  talesfromretail  1udtins  2014-01-04 03:13:28
# 296          tablets           gaming  1udxa4s  2014-01-04 06:31:53
# 297         dadjokes             pics  1udxkus  2014-01-04 05:40:07
# 298      audiorepair      techsupport  1udzbos  2014-01-03 11:20:46
# 299       canadaguns    adviceanimals   1udzhr  2014-01-04 09:05:50
#
#      LINK_SENTIMENT                                         PROPERTIES
# 0                 1  345.0,298.0,0.75652173913,0.0173913043478,0.08...
# 1                -1  101.0,98.0,0.742574257426,0.019801980198,0.049...
# 2                 1  85.0,85.0,0.752941176471,0.0235294117647,0.082...
# 3                 1  1124.0,949.0,0.772241992883,0.0017793594306,0....
# 4                 1  715.0,622.0,0.777622377622,0.00699300699301,0....
# ..              ...                                                ...
# 295               1  331.0,309.0,0.679758308157,0.108761329305,0.03...
# 296               1  489.0,414.0,0.779141104294,0.0081799591002,0.0...
# 297               1  98.0,98.0,0.724489795918,0.0612244897959,0.040...
# 298               1  756.0,637.0,0.775132275132,0.00925925925926,0....
# 299              -1  98.0,98.0,0.785714285714,0.0204081632653,0.061...
#
# [300 rows x 6 columns]

# %%
import csv
political_sub_list = []
with open('political_subs.txt', 'r') as fd:
    reader = csv.reader(fd)
    for row in reader:
        for element in row:
            political_sub_list.append(element)

# %%
# filter out the unnecesarry characters

for i in range(len(political_sub_list)):
#     political_sub_list[i] = political_sub_list[i].replace("\r\',' '')
    political_sub_list[i] = political_sub_list[i].replace("/r/", "")
    political_sub_list[i] = political_sub_list[i].replace(" ", "")
    political_sub_list[i] = political_sub_list[i].replace("'", "")
    political_sub_list[i] = political_sub_list[i].replace('"', "").lower()

# %%
 filtered = df.loc[df['SOURCE_SUBREDDIT'].isin(political_sub_list)]

# %%
filtered = filtered.loc[filtered['TARGET_SUBREDDIT'].isin(political_sub_list)]

# %%
filtered['TIMESTAMP']= pd.to_datetime(df['TIMESTAMP'])

# %%
filtered = filtered.sort_values(by="TIMESTAMP")

# %%
filtered[17725:17735]
# Out:
#          SOURCE_SUBREDDIT TARGET_SUBREDDIT  POST_ID           TIMESTAMP  \
# 286334     onguardforthee           canada   68d7pi 2017-04-29 19:19:10
# 286338        howardstern           movies  68db8us 2017-04-29 19:30:41
# 286435     subredditdrama        economics  68g8yws 2017-04-30 09:17:13
# 286439    enoughtrumpspam         politics  68gbmls 2017-04-30 09:28:40
# 286461          socialism             pics  68gxp8s 2017-04-30 11:07:03
# 286459  nostupidquestions        askreddit  68guqes 2017-04-30 11:09:56
# 286473              funny        askreddit   68h6sg 2017-04-30 12:05:58
# 286553         weedstocks   wallstreetbets  68ihozs 2017-04-30 14:28:25
# 286525     writingprompts   showerthoughts  68i0e2s 2017-04-30 14:36:31
# 286536              trees            india  68i8d3s 2017-04-30 15:16:34
#
#         LINK_SENTIMENT                                         PROPERTIES
# 286334              -1  1635.0,1530.0,0.74495412844,0.0470948012232,0....
# 286338               1  128.0,128.0,0.7421875,0.0859375,0.0703125,0.00...
# 286435               1  258.0,242.0,0.717054263566,0.062015503876,0.03...
# 286439               1  542.0,499.0,0.79520295203,0.0110701107011,0.03...
# 286461               1  1904.0,1702.0,0.773634453782,0.0241596638655,0...
# 286459               1  438.0,394.0,0.796803652968,0.00456621004566,0....
# 286473              -1  313.0,292.0,0.741214057508,0.0287539936102,0.0...
# 286553               1  870.0,748.0,0.766666666667,0.00459770114943,0....
# 286525               1  189.0,181.0,0.746031746032,0.0634920634921,0.0...
# 286536               1  11033.0,9934.0,0.776398078492,0.0182180730536,...

# %%
import datetime as dt

segments_data['date'] = segments_data.time.dt.date
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-111-451410dc6ac0> in <module>
# ----> 1 time_2014 = filtered.loc[filtered['TIMESTAMP'][0:4].isin(time_list)]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
# -> 1090             return self._getbool_axis(key, axis=axis)
#    1091         elif is_list_like_indexer(key):
#    1092
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#     894         # caller is responsible for ensuring non-None axis
#     895         labels = self.obj._get_axis(axis)
# --> 896         key = check_bool_indexer(labels, key)
#     897         inds = key.nonzero()[0]
#     898         return self.obj._take_with_is_copy(inds, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2182         mask = isna(result._values)
#    2183         if mask.any():
# -> 2184             raise IndexingError(
#    2185                 "Unalignable boolean Series provided as "
#    2186                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
time_2014
# Out:
# Empty DataFrame
# Columns: [SOURCE_SUBREDDIT, TARGET_SUBREDDIT, POST_ID, TIMESTAMP, LINK_SENTIMENT, PROPERTIES]
# Index: []

# %%
filtered[8000:8500]
# Out:
#        SOURCE_SUBREDDIT   TARGET_SUBREDDIT  POST_ID            TIMESTAMP  \
# 123782        copypasta   topmindsofreddit  3jzij0s  2015-09-07 18:10:23
# 123787       literature              books  3jzl38s  2015-09-07 17:29:58
# 123805      circlebroke          worldnews   3jzw4p  2015-09-07 19:41:22
# 123812  shitliberalssay             videos  3k0143s  2015-09-07 20:02:37
# 123821            india      todayilearned  3k05nas  2015-09-07 19:53:36
# ...                 ...                ...      ...                  ...
# 131554       conspiracy               news  3o33m4s  2015-10-09 12:05:18
# 131680   writingprompts          askreddit   3o41uu  2015-10-09 16:44:52
# 131686        askreddit     publicfreakout  3o45has  2015-10-09 17:08:04
# 131718           movies          askreddit  3o4he4s  2015-10-09 18:32:27
# 131723    askhistorians  mildlyinteresting  3o4joas  2015-10-09 18:48:55
#
#         LINK_SENTIMENT                                         PROPERTIES
# 123782               1  3407.0,2810.0,0.786028764309,0.00176108012915,...
# 123787               1  339.0,309.0,0.725663716814,0.0294985250737,0.0...
# 123805              -1  757.0,657.0,0.764861294584,0.00924702774108,0....
# 123812               1  95.0,95.0,0.768421052632,0.0210526315789,0.042...
# 123821               1  106.0,106.0,0.792452830189,0.00943396226415,0....
# ...                ...                                                ...
# 131554               1  333.0,292.0,0.744744744745,0.015015015015,0.03...
# 131680              -1  367.0,325.0,0.768392370572,0.0136239782016,0.0...
# 131686               1  456.0,409.0,0.769736842105,0.00877192982456,0....
# 131718               1  599.0,509.0,0.786310517529,0.00333889816361,0....
# 131723               1  441.0,389.0,0.757369614512,0.0272108843537,0.0...
#
# [500 rows x 6 columns]
